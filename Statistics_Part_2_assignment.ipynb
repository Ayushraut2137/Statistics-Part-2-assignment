# %% [markdown]
# ## Statistics Part 2 assignment

# %% [markdown]
# 1. What is hypothesis testing in statistics?
# --> Hypothesis testing is a method used to decide whether there is enough evidence in a sample of data to infer that a certain condition is true for the entire population.
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
# --> The null hypothesis is the default assumption that there is no effect, no difference, or no relationship.
#
# The alternative hypothesis is what you’re trying to prove — that there is an effect, a difference, or a relationship.
#
# 3. What is the significance level in hypothesis testing, and why is it important?
# --> The significance level, often denoted as α (alpha), is the threshold you set to decide whether a result is statistically significant.
#
# It represents the probability of rejecting the null hypothesis (H₀) when it is actually true — in other words, the chance of a false positive, also called a Type I error.
#
# Sets the bar for evidence :
#
# If your p-value ≤ α, the result is considered statistically significant, and you reject the null hypothesis.
#
# Controls the risk of being wrong:
#
# By setting α, you're deciding how much risk of error you're willing to accept.
#
# Helps make consistent decisions:
#
# It gives a clear rule for when to accept or reject H₀, reducing subjectivity.
#
# 4. What does a P-value represent in hypothesis testing?
# --> The p-value is the probability of getting your observed results (or something more extreme) if the null hypothesis is true.
#
# A small p-value means your data doesn’t look like what you'd expect under the null — so you might have discovered something interesting.
#
# 5.  How do you interpret the P-value in hypothesis testing?
# --> The p-value tells you how likely your sample results are if the null hypothesis (H₀) is true.
#
# If p-value ≤ α (e.g., 0.05):
#
#  Reject the null hypothesis (H₀)
#
#  Your results are statistically significant
#
#  You have enough evidence to support the alternative hypothesis (H₁)
#
# If p-value > α:
#
#  Fail to reject H₀
#
#  Your results are not statistically significant
#
#  There’s not enough evidence to support H₁ (but it doesn’t mean H₀ is true!)
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
# --> a. Type I Error (False Positive):
#
# You reject the null hypothesis (H₀) when it's actually true.
#
# The significance level (like 0.05) is the probability of making a Type I error.
#
# b. Type II Error (False Negative):
#
# You fail to reject H₀ when it's actually false
#
# The probability of making a Type II error (and 1 - β is called the power of the test — the ability to detect an actual effect).
#
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
# --> a. One-Tailed Test (Directional Test):
#
# You're testing for an effect in only one direction — either greater than or less than.
#
#  Example:
#
# You want to know if a new drug increases recovery rates (not just changes it, but increases).
#
# H₀: Recovery rate is ≤ 70%
#
# H₁: Recovery rate is > 70%
#
# Use when:
#
# You have a clear reason to believe the effect will go in one direction only.
#
# b. Two-Tailed Test (Non-Directional Test):
#
# You're testing for an effect in either direction — greater than OR less than.
#
# Example:
#
# You want to test if a new teaching method changes student scores (could go up or down).
#
# H₀: Average score = 75
#
# H₁: Average score ≠ 75
#
#  You care whether the score increased or decreased, just that it's different.
#
#  Use when:
# You're checking for any change, and don't want to miss a significant difference in either direction.
#
# 8. What is the Z-test, and when is it used in hypothesis testing?
# -->A Z-test is a statistical test used to determine whether there is a significant difference between a sample statistic and a population parameter (or between two samples), under the assumption that the data is normally distributed.
#
# You use a Z-test when all of the following apply:
#
#  The sample size is large (typically n ≥ 30).
#
#  The population standard deviation (σ) is known.
#
#  The data is (approximately) normally distributed or n is large enough to apply the Central Limit Theorem.
#
# 9.  How do you calculate the Z-score, and what does it represent in hypothesis testing?
# --> The general formula for the Z-score (for a one-sample Z-test) is:
#
# 𝑍 = 𝑥 -𝜇 / 𝜎 / 𝑛
#
# Where:
# 𝑥 = sample mean
#
# μ = population mean (under the null hypothesis)
#
# σ = population standard deviation
#
# n = sample size
#
# The Z-score tells you how many standard errors your sample mean is from the population mean.
#
#  Positive Z-score:
# Sample mean is above the population mean
#
#  Negative Z-score:
# Sample mean is below the population mean
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
# --> The T-distribution is a probability distribution that is similar to the normal distribution, but has heavier tails (more variability). This accounts for the extra uncertainty when you don’t know the population standard deviation (σ).
#
# It’s used when:
#
# You have a small sample size (n < 30)
#
# The population standard deviation is unknown
#
# The data is approximately normally distributed
#
# 11. What is the difference between a Z-test and a T-test?
# --> The Z-test and T-test are both used in hypothesis testing to compare means, but they’re used in different situations based on what you know about your data — especially the sample size and whether you know the population standard deviation.
#
# a. Z-test:
#
# A Z-test is used when the population standard deviation (σ) is known.
#
# It is generally applied when the sample size is large (typically n ≥ 30), where the Central Limit Theorem ensures that the sampling distribution of the mean is approximately normal.
#
# The test statistic follows a standard normal distribution (Z-distribution).
#
# It assumes that the data is normally distributed, or the sample size is large enough to justify the approximation.
#
# b. T-test:
#
# A T-test is used when the population standard deviation is unknown.
#
# It is typically used when the sample size is small (usually n < 30).
#
# The test statistic follows a T-distribution, which has heavier tails than the normal distribution, accounting for the additional uncertainty from estimating the standard deviation from the sample.
#
# The shape of the T-distribution depends on the degrees of freedom (df = n - 1) and becomes more similar to the normal distribution as the sample size increases.
#
# 12. What is the T-test, and how is it used in hypothesis testing?
# --> The T-test is a statistical hypothesis test used to determine whether there is a significant difference between the means of two groups (or between a sample mean and a known population mean) when the population standard deviation is unknown and/or the sample size is small.
#
# It is based on the t-distribution, which accounts for the additional uncertainty due to estimating the population standard deviation from the sample.
#
# How is it used in hypothesis testing:
#
# a. State the hypotheses:
#
# Null hypothesis (H₀): No difference or effect
#
# Alternative hypothesis (H₁): There is a difference
#
# b. Choose a significance level (α):
#
# Common values: 0.05, 0.01
#
# c. Calculate the T-statistic using the formula.
#
# d. Find the critical value from the T-distribution table or compute the p-value.
#
# e. Make a decision:
#
# If |t| > critical value or p-value < α, reject H₀.
#
# Otherwise, fail to reject H₀.
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
# --> The Z-test and the T-test are both statistical tests used in hypothesis testing to determine whether there is a significant difference between a sample statistic (such as the mean) and a known or hypothesized population parameter, or between the means of two samples.
#
# While they are used for similar purposes, they are theoretically distinct based on the assumptions made about the data and the distribution of the test statistic.
#
# a. Z-test (Based on Normal Distribution)
#
# The Z-test assumes that the population standard deviation (σ) is known.
#
# It is used primarily when the sample size is large (typically n ≥ 30).
#
# The test statistic follows a standard normal distribution (also called the Z-distribution).
#
# The Z-test relies on the Central Limit Theorem, which states that the sampling distribution of the mean approaches normality as the sample size increases.
#
# b. T-test (Based on T-distribution)
#
# The T-test is used when the population standard deviation is unknown.
#
# Instead of σ, the sample standard deviation (s) is used, introducing more variability.
#
# The test statistic follows a Student’s t-distribution, which has heavier tails than the normal distribution.
#
# The t-distribution varies with degrees of freedom (df = n − 1) and becomes closer to the normal distribution as the sample size increases.
#
# 14. What is a confidence interval, and how is it used to interpret statistical results?
# --> A confidence interval (CI) is a range of values used in statistics to estimate an unknown population parameter (such as a mean or proportion) based on sample data. It provides not just a single estimate, but a range of plausible values within which the true value is likely to fall.
#
# Purpose and Interpretation in Hypothesis Testing:
#
# Helps assess reliability of sample estimates.
#
# If a confidence interval includes the value in the null hypothesis, we fail to reject the null.
#
# If the interval excludes the null value, it provides evidence against the null hypothesis.
#
# 15. What is the margin of error, and how does it affect the confidence interval?
# --> The margin of error (MOE) is a measure of the maximum expected difference between the sample estimate and the true population parameter. It accounts for the uncertainty inherent in using a sample to estimate a population value.
#
# How It Affects the Confidence Interval:
#
# A larger margin of error → wider confidence interval → less precise estimate
#
# A smaller margin of error → narrower confidence interval → more precise estimate
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
# --> Bayes' Theorem is a fundamental concept in probability theory and statistics. It provides a way to update the probability of an event or hypothesis based on new evidence or information. The theorem is particularly useful when you need to revise your beliefs about a situation as new data becomes available.
#
# Bayes' Theorem is particularly useful for updating probabilities in situations where:
#
# You have prior knowledge about the probability of an event (called the prior probability).
#
# You then obtain new data or evidence that allows you to update that probability to reflect the new information (the posterior probability).
#
# In statistical contexts, Bayes' Theorem is used in:
#
# Statistical Inference: Making predictions or decisions about populations based on sample data.
#
# Machine Learning: Algorithms like Naive Bayes classification use Bayes' Theorem to classify data points.
#
# Hypothesis Testing: Updating the belief about the likelihood of a hypothesis based on observed data.
#
# Significance of Bayes' Theorem:
#
# Incorporates Prior Knowledge:
#
# Bayes' Theorem allows you to use prior information (what you knew before seeing the evidence) in combination with new evidence. This is powerful when you have prior experience or expert opinion to inform the probabilities.
#
# Provides a Framework for Updating Beliefs:
#
# As new data is observed, Bayes' Theorem allows you to update your belief (probability) about the likelihood of an event. This is crucial in dynamic systems where evidence is continually added.
#
# Flexibility in Handling Uncertainty:
#
# It helps in situations of uncertainty or partial information, where you don't have full knowledge of all possible outcomes but want to make the best decision based on available evidence.
#
# Applicable to a Wide Range of Problems:
#
# Bayes' Theorem is not limited to one specific area. It's widely used in fields like medicine, finance, engineering, and artificial intelligence.
#
# 17.  What is the Chi-square distribution, and when is it used?
# --> The Chi-square distribution is a probability distribution that is commonly used in statistics, especially in hypothesis testing and confidence interval estimation. It is a special case of the gamma distribution and is used to test the goodness-of-fit, independence, and homogeneity of categorical data.
#
#  When to Use the Chi-Square Distribution:
#
# The Chi-square distribution is typically used when:
#
# The data is categorical, meaning the variables can be grouped into categories (nominal or ordinal).
#
# You are conducting tests such as:
#
# Goodness-of-fit (comparing observed vs. expected frequencies).
#
# Test of independence (checking if two variables are related).
#
# Test of homogeneity (comparing proportions across different groups).
#
# The sample size is sufficiently large to ensure the validity of the test (typically expected frequencies should be at least 5).
#
# 18. What is the Chi-square goodness of fit test, and how is it applied?
# --> The Chi-square goodness of fit test is a statistical test used to determine if a sample data matches an expected theoretical distribution. It is applied when you have categorical data and you want to assess whether the observed frequencies in each category are consistent with a predicted distribution.
#
# This test compares the observed frequencies (the actual data you have) to the expected frequencies (the theoretical values under the null hypothesis), and it helps determine whether the differences are due to random chance or whether they are statistically significant.
#
# Steps to Perform the Chi-Square Goodness of Fit Test:
#
# State the hypotheses:
#
# Null hypothesis (H₀): The observed frequencies follow the expected distribution.
#
# Alternative hypothesis (H₁): The observed frequencies do not follow the expected distribution.
#
# Determine the expected frequencies:
#
# For each category, calculate the expected frequency using the given theoretical distribution. Often, these are based on proportions or probabilities provided in the problem.
#
# Calculate the Chi-square statistic:
#
# Use the formula to compute the test statistic by comparing the observed frequencies with the expected frequencies.
#
# Make a decision:
#
# If the test statistic is greater than the critical value, reject the null hypothesis.
#
# If the p-value is smaller than the significance level, reject the null hypothesis.
#
# 19. What is the F-distribution, and when is it used in hypothesis testing?
# --> The F-distribution is a probability distribution that arises in variance analysis and is primarily used in hypothesis testing involving two variances. It is commonly used in tests like the ANOVA (Analysis of Variance) test and the F-test for comparing variances.
#
# The F-distribution is primarily used in the following scenarios:
#
# Comparing Two Variances:
#
# The F-test is used to compare the variances of two populations to determine if they are significantly different.
#
# Example: You might use an F-test to compare the variability in exam scores between two different classes to see if one class has significantly more variability than the other.
#
# Analysis of Variance (ANOVA):
#
# ANOVA is used to test the hypothesis that the means of two or more groups are all equal. ANOVA tests the variance between groups relative to the variance within groups.
#
# Example: A researcher wants to know if there is a significant difference in the mean heights of plants grown under three different light conditions. ANOVA would be used to test if the variance between the groups (light conditions) is significantly greater than the variance within each group (variability in plant heights).
#
# Regression Analysis:
#
# The F-test is used in multiple regression to test the overall significance of the regression model.
#
# Example: In a regression model predicting sales based on multiple factors like advertising spend, number of employees, and product price, the F-test can be used to determine whether the model as a whole significantly explains the variation in sales.
#
# 20. What is an ANOVA test, and what are its assumptions?
# --> ANOVA (Analysis of Variance) is a statistical test used to compare the means of three or more groups to determine if there is a statistically significant difference between them. It is an extension of the t-test, which compares the means of two groups, and it helps to avoid type I errors when comparing multiple groups.
#
# ANOVA tests whether the variability between groups is significantly greater than the variability within groups. In other words, it checks if the differences in means between groups are larger than what would be expected by random chance.
#
#  Assumptions of ANOVA:
# For the results of an ANOVA test to be valid, certain assumptions must be met. These assumptions ensure that the test produces accurate and reliable results. The key assumptions are:
#
# Independence of Observations:
#
# The observations within each group must be independent of each other. This means that the value of one observation should not influence the value of another observation.
#
# Normality:
#
# The data within each group should follow a normal distribution. This assumption is particularly important when the sample sizes are small. If the sample sizes are large, the Central Limit Theorem helps in relaxing the normality assumption.
#
# Homogeneity of Variances (Homoscedasticity):
#
# The variance within each of the groups being compared should be approximately equal. This assumption is crucial because ANOVA compares the variability between and within groups. If the variances are unequal, the F-statistic might not be reliable.
#
# A formal test for this assumption is the Levene's Test or Bartlett's Test, which test whether the variances are equal across groups.
#
# 21. What are the different types of ANOVA tests?
# --> ANOVA (Analysis of Variance) has different types based on the structure of the experiment and the nature of the data being analyzed. The most common types of ANOVA are:
#
# a. One-Way ANOVA
#
# b. Two-Way ANOVA
#
# c. Repeated Measures ANOVA
#
# d. Multivariate Analysis of Variance (MANOVA)
#
# a. One-Way ANOVA:
#
# One-Way ANOVA is the simplest form of ANOVA. It is used when there is one independent variable (factor) with three or more levels (groups), and the goal is to compare the means of these different groups to see if there is a significant difference.
#
# Use Case: Comparing the means of several groups to see if at least one group is different from the others.
#
# Example: Testing the effectiveness of three different teaching methods (Method A, Method B, and Method C) on student performance.
#
# b. Two-Way ANOVA:
#
# Two-Way ANOVA is used when there are two independent variables (factors). This type of ANOVA helps to:
#
# Assess the individual effects of each factor on the dependent variable.
#
# Examine the interaction effect between the two factors.
#
# Use Case: When you want to study the impact of two factors and their interaction on a dependent variable.
#
# Example: Testing the impact of two factors, type of fertilizer (Factor 1: Fertilizer A, B, C) and watering frequency (Factor 2: Daily, Weekly), on plant growth.
#
# c. Repeated Measures ANOVA:
#
# Repeated Measures ANOVA is used when the same subjects are used in all groups or when multiple measurements are taken from the same group at different points in time. It is used to analyze the impact of an independent variable (or variables) on a dependent variable when the data are collected repeatedly from the same subjects.
#
# Use Case: Testing how a treatment or condition affects the same group of subjects over time or under different conditions.
#
# Example: Measuring the effect of a drug on blood pressure in the same group of patients at different time points (before treatment, during treatment, and after treatment).
#
# d. Multivariate Analysis of Variance (MANOVA):
#
# MANOVA is an extension of ANOVA that is used when there are multiple dependent variables that are correlated. It tests whether the means of the multiple dependent variables differ across groups.
#
# Use Case: When you want to test the effect of one or more independent variables on two or more dependent variables simultaneously.
#
# Example: Testing the effects of different diets on both weight loss and cholesterol levels.
#
# 22. What is the F-test, and how does it relate to hypothesis testing?
# --> The F-test is a statistical test used to compare variances between two or more groups or populations. It is based on the F-distribution and is commonly used to test the hypothesis that two populations have the same variance. The F-test is a key part of Analysis of Variance (ANOVA) and can also be used in regression analysis to compare models.
#
# The F-test is commonly used in the context of hypothesis testing to test whether there are significant differences between the variances of two or more groups. The basic steps for conducting an F-test in hypothesis testing are as follows:
#
# State the Hypotheses:
#
# Null Hypothesis (H₀): The variances of the populations (or groups) are equal. (For ANOVA, this would be that the group means are all equal.)
#
# Alternative Hypothesis (H₁): The variances (or group means) are not equal.
#
# Choose a Significance Level (α):
#
# Typically, 𝛼 = 0.05 (5% significance level), which means you are willing to accept a 5% chance of rejecting the null hypothesis when it is actually true.
#
# Calculate the F-statistic:
#
# Compute the variance between groups and the variance within groups and calculate the F-statistic.
#
# Find the Critical Value:
#
# Use an F-distribution table or statistical software to find the critical value of the F-statistic based on the degrees of freedom for the numerator and denominator, and the significance level (α).
#
#
# Make a Decision:
#
# If the calculated F-statistic is greater than the critical value (or if the p-value is less than α), reject the null hypothesis. This means there is a significant difference in variances (or group means).
#
# If the calculated F-statistic is less than the critical value (or if the p-value is greater than α), fail to reject the null hypothesis. This means the variances (or group means) are not significantly different.

# %%
# Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results

import numpy as np
from scipy import stats

sample_data = [50, 55, 53, 49, 52, 51, 56, 50, 52, 54]
sample_mean = np.mean(sample_data)
sample_size = len(sample_data)
sample_std_dev = np.std(sample_data, ddof=1)
population_mean = 50  # The known population mean
population_std_dev = 10  # The known population standard deviation (assumed)

# Perform the Z-test
z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))

# Calculate the p-value for a two-tailed test
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Output the results
print("Sample Mean:", sample_mean)
print("Sample Size:", sample_size)
print("Sample Standard Deviation:", sample_std_dev)
print("Z-Score:", z_score)
print("P-Value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level (5%)
if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant difference between the sample mean and the population mean.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.")
# Out:
# Sample Mean: 52.2
# Sample Size: 10
# Sample Standard Deviation: 2.2997584414213783
# Z-Score: 0.6957010852370444
# P-Value: 0.48661604576405004
#
# Fail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.

# %%
# Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python

import numpy as np
from scipy import stats


np.random.seed(42)  # For reproducibility
sample_size = 30
population_mean = 50
population_std_dev = 10

sample_data = np.random.normal(loc=population_mean, scale=population_std_dev, size=sample_size)

sample_mean = np.mean(sample_data)
sample_std_dev = np.std(sample_data, ddof=1)  # Sample standard deviation (ddof=1 for sample)
sample_size = len(sample_data)

z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))

p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

print("Sample Mean:", sample_mean)
print("Sample Size:", sample_size)
print("Sample Standard Deviation:", sample_std_dev)
print("Z-Score:", z_score)
print("P-Value:", p_value)

alpha = 0.05  # Significance level (5%)
if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant difference between the sample mean and the population mean.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.")
# Out:
# Sample Mean: 48.118531041489625
# Sample Size: 30
# Sample Standard Deviation: 9.000064274024114
# Z-Score: -1.0305229898218837
# P-Value: 0.3027645658813325
#
# Fail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.

# %%
#  Implement a one-sample Z-test using Python to compare the sample mean with the population mean

import numpy as np
from scipy import stats

# Sample data
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=100, scale=15, size=50)  # Simulate sample data with mean=100 and std=15
sample_mean = np.mean(sample_data)
sample_std_dev = np.std(sample_data, ddof=1)  # Sample standard deviation (ddof=1 for sample)
sample_size = len(sample_data)

# Population parameters
population_mean = 100  # Known population mean
population_std_dev = 15  # Known population standard deviation

# Step 1: Calculate the Z-score
z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))

# Step 2: Calculate the P-value for a two-tailed test
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Output the results
print("Sample Mean:", sample_mean)
print("Sample Size:", sample_size)
print("Sample Standard Deviation:", sample_std_dev)
print("Z-Score:", z_score)
print("P-Value:", p_value)

# Step 3: Interpret the results
alpha = 0.05  # Significance level (5%)
if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant difference between the sample mean and the population mean.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.")
# Out:
# Sample Mean: 96.61789142115789
# Sample Size: 50
# Sample Standard Deviation: 14.005031728246673
# Z-Score: -1.5943412738723008
# P-Value: 0.1108596180002146
#
# Fail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.

# %%
#  Perform a two-tailed Z-test using Python and visualize the decision region on a plot

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Simulate sample data
np.random.seed(42)  # For reproducibility
population_mean = 100
population_std_dev = 15
sample_size = 50

# Simulate sample data
sample_data = np.random.normal(loc=population_mean, scale=population_std_dev, size=sample_size)
sample_mean = np.mean(sample_data)
sample_std_dev = np.std(sample_data, ddof=1)  # Sample standard deviation
sample_size = len(sample_data)

# Step 2: Perform Z-test
z_score = (sample_mean - population_mean) / (population_std_dev / np.sqrt(sample_size))

# Two-tailed test - calculate the p-value
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Step 3: Visualize the decision region
alpha = 0.05  # Significance level

# Calculate the critical values for two-tailed test
z_critical_left = stats.norm.ppf(alpha / 2)
z_critical_right = stats.norm.ppf(1 - alpha / 2)

# Create x values for plotting the normal distribution
x = np.linspace(population_mean - 4*population_std_dev, population_mean + 4*population_std_dev, 1000)
y = stats.norm.pdf(x, loc=population_mean, scale=population_std_dev)

# Plot the normal distribution
plt.plot(x, y, label='Normal Distribution', color='blue')

# Fill the rejection regions
plt.fill_between(x, y, 0, where=(x <= z_critical_left) | (x >= z_critical_right), color='red', alpha=0.5, label='Rejection Region')

# Add critical z-values and sample mean line
plt.axvline(z_critical_left, color='red', linestyle='dashed', label=f'Z-Critical Left = {z_critical_left:.2f}')
plt.axvline(z_critical_right, color='red', linestyle='dashed', label=f'Z-Critical Right = {z_critical_right:.2f}')
plt.axvline(sample_mean, color='green', linestyle='dashed', label=f'Sample Mean = {sample_mean:.2f}')

# Labels and title
plt.title('Two-Tailed Z-Test - Decision Region')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# Step 4: Interpret the results
print("Sample Mean:", sample_mean)
print("Z-Score:", z_score)
print("P-Value:", p_value)

if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant difference between the sample mean and the population mean.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.")
# Out:
# Sample Mean: 96.61789142115789
# Z-Score: -1.5943412738723008
# P-Value: 0.1108596180002146
#
# Fail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.

# %%
#  Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

def visualize_type_errors(population_mean, population_std_dev, sample_size, alternative_mean, alpha=0.05):
    # Step 1: Generate the x values for plotting
    x = np.linspace(population_mean - 4 * population_std_dev, population_mean + 4 * population_std_dev, 1000)

    # Step 2: Create the normal distributions for the null hypothesis (H0) and alternative hypothesis (H1)
    # Null hypothesis (H0)
    y0 = stats.norm.pdf(x, loc=population_mean, scale=population_std_dev)
    # Alternative hypothesis (H1)
    y1 = stats.norm.pdf(x, loc=alternative_mean, scale=population_std_dev)

    # Step 3: Calculate critical values for the Z-test (two-tailed test)
    z_critical_left = stats.norm.ppf(alpha / 2)
    z_critical_right = stats.norm.ppf(1 - alpha / 2)

    # Step 4: Calculate the Type I error (α) and Type II error (β)
    # Type I error: the area in the rejection region under the null hypothesis curve
    type_1_error = 1 - stats.norm.cdf(z_critical_right, loc=population_mean, scale=population_std_dev) + stats.norm.cdf(z_critical_left, loc=population_mean, scale=population_std_dev)

    # Type II error: the area in the non-rejection region under the alternative hypothesis curve
    type_2_error_left = stats.norm.cdf(z_critical_left, loc=alternative_mean, scale=population_std_dev)
    type_2_error_right = 1 - stats.norm.cdf(z_critical_right, loc=alternative_mean, scale=population_std_dev)
    type_2_error = type_2_error_left + type_2_error_right

    # Step 5: Visualize the decision region, Type I error, and Type II error
    plt.plot(x, y0, label='Null Hypothesis (H0)', color='blue')
    plt.plot(x, y1, label='Alternative Hypothesis (H1)', color='green')

    # Fill rejection regions (Type I Error regions)
    plt.fill_between(x, y0, 0, where=(x <= z_critical_left) | (x >= z_critical_right), color='red', alpha=0.5, label=f'Type I Error (α) Area')

    # Fill Type II Error regions
    plt.fill_between(x, y1, 0, where=(x >= z_critical_left) & (x <= z_critical_right), color='yellow', alpha=0.5, label=f'Type II Error (β) Area')

    # Add critical value lines
    plt.axvline(z_critical_left, color='red', linestyle='dashed', label=f'Z-Critical Left = {z_critical_left:.2f}')
    plt.axvline(z_critical_right, color='red', linestyle='dashed', label=f'Z-Critical Right = {z_critical_right:.2f}')

    # Add labels and legend
    plt.title('Type I and Type II Errors Visualization')
    plt.xlabel('Value')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Print error values
    print(f"Type I Error (α): {type_1_error:.4f}")
    print(f"Type II Error (β): {type_2_error:.4f}")

# Example usage
population_mean = 100
population_std_dev = 15
sample_size = 30
alternative_mean = 105  # Hypothetical alternative population mean

visualize_type_errors(population_mean, population_std_dev, sample_size, alternative_mean, alpha=0.05)
# Out:
# Type I Error (α): 1.0000
# Type II Error (β): 1.0000

# %%
# Write a Python program to perform an independent T-test and interpret the results

import numpy as np
from scipy import stats

# Simulating two independent samples (Group A and Group B)
np.random.seed(42)  # For reproducibility

# Sample data for Group A and Group B
group_a = np.random.normal(loc=50, scale=10, size=30)  # Group A (mean=50, std=10, size=30)
group_b = np.random.normal(loc=55, scale=10, size=30)  # Group B (mean=55, std=10, size=30)

# Step 1: Perform an independent T-test
t_statistic, p_value = stats.ttest_ind(group_a, group_b)

# Step 2: Interpret the results
alpha = 0.05  # Significance level (5%)
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

# Step 3: Decision based on P-value
if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant difference between the means of Group A and Group B.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference between the means of Group A and Group B.")
# Out:
# T-statistic: -2.3981
# P-value: 0.0197
#
# Reject the null hypothesis: There is a significant difference between the means of Group A and Group B.

# %%
#  Perform a paired sample T-test using Python and visualize the comparison results

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Simulating paired sample data
np.random.seed(42)  # For reproducibility

# Simulating two related samples (before and after treatment)
before_treatment = np.random.normal(loc=100, scale=15, size=30)  # Before treatment (mean=100, std=15)
after_treatment = before_treatment + np.random.normal(loc=5, scale=10, size=30)  # After treatment (mean=5 increase)

# Step 2: Perform a paired sample T-test
t_statistic, p_value = stats.ttest_rel(before_treatment, after_treatment)

# Step 3: Interpret the results
alpha = 0.05  # Significance level
print(f"T-statistic: {t_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant difference between the paired samples.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference between the paired samples.")

# Step 4: Visualize the comparison using a boxplot
plt.figure(figsize=(8, 6))
plt.boxplot([before_treatment, after_treatment], labels=['Before Treatment', 'After Treatment'], patch_artist=True,
            boxprops=dict(facecolor='skyblue', color='blue'), medianprops=dict(color='red'))
plt.title('Comparison of Data Before and After Treatment')
plt.ylabel('Values')
plt.grid(True)
plt.show()
# Out:
# T-statistic: -2.2285
# P-value: 0.0338
#
# Reject the null hypothesis: There is a significant difference between the paired samples.
# <ipython-input-8-65b2084d2a84>:29: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([before_treatment, after_treatment], labels=['Before Treatment', 'After Treatment'], patch_artist=True,

# %%
# Simulate data and perform both Z-test and T-test, then compare the results using Python

import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Step 1: Simulate data (sample of size 30)
np.random.seed(42)  # For reproducibility

# Known population mean and standard deviation
population_mean = 50
population_std_dev = 10

# Simulating a sample data (sample mean should be close to population mean)
sample_size = 30
sample_data = np.random.normal(loc=population_mean, scale=population_std_dev, size=sample_size)

# Step 2: Perform a Z-test
# Z-test requires population standard deviation (known)
z_statistic = (np.mean(sample_data) - population_mean) / (population_std_dev / np.sqrt(sample_size))
z_p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))  # Two-tailed Z-test

# Step 3: Perform a T-test
# T-test assumes unknown population standard deviation
t_statistic, t_p_value = stats.ttest_1samp(sample_data, population_mean)

# Step 4: Output and comparison
alpha = 0.05  # Significance level

print(f"Z-test - Z-statistic: {z_statistic:.4f}, P-value: {z_p_value:.4f}")
print(f"T-test - T-statistic: {t_statistic:.4f}, P-value: {t_p_value:.4f}")

# Interpretation based on P-values
print("\nZ-test interpretation:")
if z_p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")

print("\nT-test interpretation:")
if t_p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")

# Step 5: Visualization of the sample data with a population mean
plt.figure(figsize=(8, 6))
plt.hist(sample_data, bins=10, alpha=0.7, color='skyblue', label='Sample Data')
plt.axvline(population_mean, color='red', linestyle='dashed', linewidth=2, label=f'Population Mean = {population_mean}')
plt.title('Histogram of Sample Data')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z-test - Z-statistic: -1.0305, P-value: 0.3028
# T-test - T-statistic: -1.1450, P-value: 0.2616
#
# Z-test interpretation:
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.
#
# T-test interpretation:
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %%
# Write a Python function to calculate the confidence interval for a sample mean and explain its significance

import numpy as np
from scipy import stats

def calculate_confidence_interval(sample_data, confidence_level=0.95, population_std=None):
    """
    Calculate the confidence interval for a sample mean.

    Parameters:
    sample_data (array-like): The sample data for which the confidence interval is calculated.
    confidence_level (float): The desired confidence level (default is 0.95).
    population_std (float or None): The population standard deviation. If None, sample standard deviation is used.

    Returns:
    tuple: Lower and upper bounds of the confidence interval.
    """
    # Step 1: Calculate sample mean and sample size
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    # Step 2: Calculate sample standard deviation
    sample_std = np.std(sample_data, ddof=1)

    # Step 3: Determine whether to use Z-distribution (if population_std is provided) or T-distribution
    if population_std is not None:
        # Z-distribution (known population std)
        standard_error = population_std / np.sqrt(sample_size)
        z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)  # Z-score for two-tailed test
    else:
        # T-distribution (if population std is unknown)
        standard_error = sample_std / np.sqrt(sample_size)
        degrees_of_freedom = sample_size - 1
        t_score = stats.t.ppf(1 - (1 - confidence_level) / 2, df=degrees_of_freedom)  # T-score for two-tailed test

    # Step 4: Calculate the margin of error
    margin_of_error = t_score * standard_error if population_std is None else z_score * standard_error

    # Step 5: Calculate the confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# Example usage
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=50, scale=10, size=30)  # Simulating a sample with mean=50, std=10

confidence_interval = calculate_confidence_interval(sample_data, confidence_level=0.95)
print(f"The 95% confidence interval for the sample mean is: {confidence_interval}")
# Out:
# The 95% confidence interval for the sample mean is: (np.float64(44.75785181035169), np.float64(51.47921027262756))

# %%
#  Write a Python program to calculate the margin of error for a given confidence level using sample data

import numpy as np
from scipy import stats

def calculate_margin_of_error(sample_data, confidence_level=0.95, population_std=None):
    """
    Calculate the margin of error for a sample given a confidence level.

    Parameters:
    sample_data (array-like): The sample data.
    confidence_level (float): The desired confidence level (default is 0.95).
    population_std (float or None): The population standard deviation. If None, the sample standard deviation is used.

    Returns:
    float: The margin of error.
    """
    # Step 1: Calculate the sample mean and sample size
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    # Step 2: Calculate the sample standard deviation
    sample_std = np.std(sample_data, ddof=1)

    # Step 3: Determine whether to use Z-distribution or T-distribution
    if population_std is not None:
        # Z-distribution (known population std)
        standard_error = population_std / np.sqrt(sample_size)
        z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)  # Z-score for two-tailed test
        margin_of_error = z_score * standard_error
    else:
        # T-distribution (unknown population std, use sample std)
        standard_error = sample_std / np.sqrt(sample_size)
        degrees_of_freedom = sample_size - 1
        t_score = stats.t.ppf(1 - (1 - confidence_level) / 2, df=degrees_of_freedom)  # T-score for two-tailed test
        margin_of_error = t_score * standard_error

    return margin_of_error

# Example usage
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=50, scale=10, size=30)  # Simulating a sample with mean=50, std=10

# Calculate margin of error for 95% confidence level
margin_of_error = calculate_margin_of_error(sample_data, confidence_level=0.95)
print(f"The margin of error at 95% confidence level is: {margin_of_error:.4f}")
# Out:
# The margin of error at 95% confidence level is: 3.3607

# %%
# Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process

def bayesian_inference(prior, likelihood, evidence, false_positive_rate):
    """
    Perform Bayesian inference using Bayes' Theorem.

    Parameters:
    prior (float): Prior probability P(H), the initial belief about the hypothesis.
    likelihood (float): Likelihood P(E|H), the probability of observing the evidence given the hypothesis.
    evidence (float): The total probability of observing the evidence P(E).
    false_positive_rate (float): The false positive rate P(E|~H), the probability of observing the evidence assuming the hypothesis is false.

    Returns:
    float: The posterior probability P(H|E), the updated probability of the hypothesis given the evidence.
    """
    # Bayes' Theorem: P(H|E) = (P(E|H) * P(H)) / P(E)
    posterior = (likelihood * prior) / evidence
    return posterior

def calculate_evidence(likelihood, prior, false_positive_rate):

    # P(E) = P(E|H) * P(H) + P(E|~H) * P(~H)
    # P(~H) = 1 - P(H)
    p_not_h = 1 - prior
    evidence = (likelihood * prior) + (false_positive_rate * p_not_h)
    return evidence

# Given values:
prior = 0.01  # Prior probability of having the disease (1%)
likelihood = 0.99  # Probability of a positive test result given the person has the disease
false_positive_rate = 0.05  # Probability of a false positive (person doesn't have the disease, but the test is positive)

# Step 1: Calculate the evidence P(E)
evidence = calculate_evidence(likelihood, prior, false_positive_rate)

# Step 2: Apply Bayes' Theorem to calculate the posterior probability P(H|E)
posterior = bayesian_inference(prior, likelihood, evidence, false_positive_rate)

# Output the result
print(f"The posterior probability of having the disease given a positive test result is: {posterior:.4f}")
# Out:
# The posterior probability of having the disease given a positive test result is: 0.1667

# %%
# D Perform a Chi-square test for independence between two categorical variables in Python

import numpy as np
from scipy.stats import chi2_contingency

# Create the contingency table
data = np.array([[30, 70],  # Male: [Smoker, Non-smoker]
                 [20, 80]]) # Female: [Smoker, Non-smoker]

# Perform the Chi-square test for independence
chi2, p, dof, expected = chi2_contingency(data)

# Output the results
print(f"Chi-square statistic: {chi2:.4f}")
print(f"P-value: {p:.4f}")
print(f"Degrees of freedom: {dof}")
print(f"Expected frequencies:\n{expected}")

# Interpretation
alpha = 0.05  # Significance level

if p < alpha:
    print("\nWe reject the null hypothesis: There is a significant association between gender and smoking status.")
else:
    print("\nWe fail to reject the null hypothesis: There is no significant association between gender and smoking status.")
# Out:
# Chi-square statistic: 2.1600
# P-value: 0.1416
# Degrees of freedom: 1
# Expected frequencies:
# [[25. 75.]
#  [25. 75.]]
#
# We fail to reject the null hypothesis: There is no significant association between gender and smoking status.

# %%
# Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data

import numpy as np

def calculate_expected_frequencies(observed):
    # Get the row totals and column totals
    row_totals = observed.sum(axis=1)
    column_totals = observed.sum(axis=0)

    # Calculate the grand total
    grand_total = observed.sum()

    # Calculate the expected frequencies using the formula
    expected = np.outer(row_totals, column_totals) / grand_total

    return expected

# Given observed data (contingency table)
observed_data = np.array([[30, 70],  # Male: [Smoker, Non-smoker]
                          [20, 80]]) # Female: [Smoker, Non-smoker]

# Calculate expected frequencies
expected_frequencies = calculate_expected_frequencies(observed_data)

# Print the observed and expected frequencies
print("Observed Frequencies:\n", observed_data)
print("\nExpected Frequencies:\n", expected_frequencies)
# Out:
# Observed Frequencies:
#  [[30 70]
#  [20 80]]
#
# Expected Frequencies:
#  [[25. 75.]
#  [25. 75.]]

# %%
# Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution

import numpy as np
from scipy.stats import chisquare

# Observed frequencies (from the die roll experiment)
observed_frequencies = np.array([10, 12, 8, 7, 11, 12])

# Expected frequencies for a fair die (each outcome should have an equal probability)
expected_frequencies = np.array([10, 10, 10, 10, 10, 10])  # Expected for each face: 60 rolls / 6 faces = 10

# Perform the Chi-Square Goodness-of-Fit test
chi2_stat, p_value = chisquare(observed_frequencies, expected_frequencies)

# Output the results
print(f"Chi-Square Statistic: {chi2_stat:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level

if p_value < alpha:
    print("\nWe reject the null hypothesis: The observed data does not follow the expected distribution.")
else:
    print("\nWe fail to reject the null hypothesis: The observed data follows the expected distribution.")
# Out:
# Chi-Square Statistic: 2.2000
# P-value: 0.8208
#
# We fail to reject the null hypothesis: The observed data follows the expected distribution.

# %%
#  Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Function to simulate and plot Chi-Square distribution
def plot_chi_square_distribution(degrees_of_freedom, num_samples=10000):
    # Simulate Chi-square distributed random variables for the given degrees of freedom
    chi_square_data = np.random.chisquare(degrees_of_freedom, num_samples)

    # Create a histogram of the simulated data
    plt.hist(chi_square_data, bins=50, density=True, alpha=0.6, color='b', label=f"Simulated (df={degrees_of_freedom})")

    # Plot the theoretical Chi-Square distribution curve
    x = np.linspace(0, np.max(chi_square_data), 1000)
    y = chi2.pdf(x, degrees_of_freedom)
    plt.plot(x, y, 'r-', label=f"Theoretical (df={degrees_of_freedom})", linewidth=2)

    # Add labels and legend
    plt.title(f"Chi-Square Distribution (df={degrees_of_freedom})")
    plt.xlabel("Value")
    plt.ylabel("Density")
    plt.legend()

    # Show the plot
    plt.show()

# Visualizing Chi-Square distributions with different degrees of freedom
for df in [1, 2, 5, 10]:
    plot_chi_square_distribution(df)

# %%
#  Implement an F-test using Python to compare the variances of two random samples

import numpy as np
from scipy.stats import f

# Function to perform the F-test for comparing variances
def f_test(sample1, sample2, alpha=0.05):
    # Calculate the variances of the two samples
    var1 = np.var(sample1, ddof=1)  # sample variance (ddof=1 for sample variance)
    var2 = np.var(sample2, ddof=1)

    # Calculate the F-statistic (larger variance / smaller variance)
    if var1 > var2:
        F_statistic = var1 / var2
        df1 = len(sample1) - 1  # degrees of freedom for sample 1
        df2 = len(sample2) - 1  # degrees of freedom for sample 2
    else:
        F_statistic = var2 / var1
        df1 = len(sample2) - 1
        df2 = len(sample1) - 1

    # Calculate the p-value using the cumulative distribution function (CDF) of the F-distribution
    p_value = 1 - f.cdf(F_statistic, df1, df2)

    # Output the results
    print(f"F-statistic: {F_statistic:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Interpretation of the results
    if p_value < alpha:
        print("\nWe reject the null hypothesis: The variances are significantly different.")
    else:
        print("\nWe fail to reject the null hypothesis: The variances are not significantly different.")

# Example: Simulate two random samples with different variances
np.random.seed(0)  # For reproducibility
sample1 = np.random.normal(loc=0, scale=1, size=50)  # Sample 1 with mean 0 and std 1
sample2 = np.random.normal(loc=0, scale=2, size=50)  # Sample 2 with mean 0 and std 2

# Perform the F-test
f_test(sample1, sample2)
# Out:
# F-statistic: 2.3739
# P-value: 0.0015
#
# We reject the null hypothesis: The variances are significantly different.

# %%
# Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results

import numpy as np
from scipy import stats

# Function to perform one-way ANOVA test
def perform_anova(*samples):
    # Perform ANOVA test
    f_statistic, p_value = stats.f_oneway(*samples)

    # Output the results
    print(f"F-statistic: {f_statistic:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Interpretation of the results
    if p_value < 0.05:
        print("\nWe reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("\nWe fail to reject the null hypothesis: No significant difference between group means.")

# Example: Simulate data for three different groups
np.random.seed(0)  # For reproducibility
group1 = np.random.normal(loc=5, scale=1, size=30)  # Group 1 with mean 5 and std 1
group2 = np.random.normal(loc=5.5, scale=1, size=30)  # Group 2 with mean 5.5 and std 1
group3 = np.random.normal(loc=6, scale=1, size=30)  # Group 3 with mean 6 and std 1

# Perform the ANOVA test
perform_anova(group1, group2, group3)
# Out:
# F-statistic: 3.3415
# P-value: 0.0400
#
# We reject the null hypothesis: At least one group mean is significantly different.

# %%
# D Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Function to perform one-way ANOVA test
def perform_anova(*samples):
    # Perform ANOVA test
    f_statistic, p_value = stats.f_oneway(*samples)

    # Output the results
    print(f"F-statistic: {f_statistic:.4f}")
    print(f"P-value: {p_value:.4f}")

    # Interpretation of the results
    if p_value < 0.05:
        print("\nWe reject the null hypothesis: At least one group mean is significantly different.")
    else:
        print("\nWe fail to reject the null hypothesis: No significant difference between group means.")

    return f_statistic, p_value

# Simulate data for multiple groups
np.random.seed(0)  # For reproducibility
group1 = np.random.normal(loc=5, scale=1, size=30)  # Group 1 with mean 5 and std 1
group2 = np.random.normal(loc=5.5, scale=1, size=30)  # Group 2 with mean 5.5 and std 1
group3 = np.random.normal(loc=6, scale=1, size=30)  # Group 3 with mean 6 and std 1

# Perform the ANOVA test
f_statistic, p_value = perform_anova(group1, group2, group3)

# Plotting the data using boxplot
plt.figure(figsize=(8, 6))
plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'], patch_artist=True)
plt.title("Boxplot of Groups for One-Way ANOVA")
plt.ylabel("Values")
plt.xlabel("Groups")

# Show the plot
plt.show()
# Out:
# F-statistic: 3.3415
# P-value: 0.0400
#
# We reject the null hypothesis: At least one group mean is significantly different.
# <ipython-input-19-48bc41fcfdc0>:35: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=['Group 1', 'Group 2', 'Group 3'], patch_artist=True)

# %%
# Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Function to check normality assumption using Shapiro-Wilk test
def check_normality(data):
    p_values = []
    for i, group in enumerate(data):
        stat, p_value = stats.shapiro(group)
        print(f"Shapiro-Wilk Test for Group {i+1}: p-value = {p_value:.4f}")
        p_values.append(p_value)
    return p_values

# Function to check the homogeneity of variances using Levene's Test
def check_equal_variance(*samples):
    stat, p_value = stats.levene(*samples)
    print(f"Levene's Test for Equal Variance: p-value = {p_value:.4f}")
    return p_value

# Function to plot the data for visual inspection of normality
def plot_normality(data):
    for i, group in enumerate(data):
        sns.distplot(group, label=f"Group {i+1}", kde=True, hist=True)
    plt.legend()
    plt.title("Distribution of Groups")
    plt.show()

# Function to create Q-Q plots to visually inspect normality
def plot_qq(data):
    for i, group in enumerate(data):
        stats.probplot(group, dist="norm", plot=plt)
        plt.title(f"Q-Q plot for Group {i+1}")
        plt.show()

# Function to perform all checks
def check_anova_assumptions(*samples):
    # Check Normality using Shapiro-Wilk test
    print("\nChecking Normality Assumption:")
    normality_p_values = check_normality(samples)

    # Plot distributions for normality check
    plot_normality(samples)

    # Check Homogeneity of Variances using Levene's test
    print("\nChecking Equal Variance Assumption:")
    p_value_variance = check_equal_variance(*samples)

    # Perform Q-Q plots for visual inspection
    plot_qq(samples)

    # Return results
    normality_check = all(p > 0.05 for p in normality_p_values)  # Normality assumption holds if all p-values > 0.05
    variance_check = p_value_variance > 0.05  # Homogeneity of variance holds if p-value > 0.05

    return normality_check, variance_check

# Example usage: Simulate data for three groups
np.random.seed(0)
group1 = np.random.normal(loc=5, scale=1, size=30)
group2 = np.random.normal(loc=5.5, scale=1, size=30)
group3 = np.random.normal(loc=6, scale=1, size=30)

# Check assumptions for ANOVA
normality_check, variance_check = check_anova_assumptions(group1, group2, group3)

# Final decision based on assumption checks
if normality_check and variance_check:
    print("\nAssumptions for ANOVA are met: Proceed with the ANOVA test.")
else:
    print("\nAssumptions for ANOVA are not met: Consider transformations or different tests.")
# Out:
# Checking Normality Assumption:
# Shapiro-Wilk Test for Group 1: p-value = 0.5254
# Shapiro-Wilk Test for Group 2: p-value = 0.9085
# Shapiro-Wilk Test for Group 3: p-value = 0.7204
# <ipython-input-20-e69927de9412>:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(group, label=f"Group {i+1}", kde=True, hist=True)
# <ipython-input-20-e69927de9412>:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# ...

# %%
# Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results

import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns

# Simulating Data
np.random.seed(0)
factor1 = np.random.choice(['A', 'B'], size=60)  # Factor 1 with levels 'A' and 'B'
factor2 = np.random.choice(['X', 'Y', 'Z'], size=60)  # Factor 2 with levels 'X', 'Y', 'Z'
response = np.random.normal(loc=0, scale=1, size=60)  # Dependent variable

# Modify data to introduce some interaction
response[(factor1 == 'A') & (factor2 == 'X')] += 1
response[(factor1 == 'B') & (factor2 == 'Y')] -= 1

# Create a DataFrame
data = pd.DataFrame({'Factor1': factor1, 'Factor2': factor2, 'Response': response})

# Perform Two-Way ANOVA
model = ols('Response ~ Factor1 * Factor2', data=data).fit()  # 'Factor1 * Factor2' includes both main effects and interaction
anova_table = sm.stats.anova_lm(model, typ=2)  # Type II ANOVA table

# Display the ANOVA table
print(anova_table)

# Visualization of the interaction effect
plt.figure(figsize=(8, 6))
sns.pointplot(x='Factor1', y='Response', hue='Factor2', data=data, dodge=True, markers='o', linestyles='-', capsize=5)
plt.title('Interaction Plot for Two-Way ANOVA')
plt.ylabel('Response')
plt.xlabel('Factor 1')
plt.show()
# Out:
#                     sum_sq    df         F    PR(>F)
# Factor1           4.877883   1.0  4.651396  0.035498
# Factor2           9.839403   2.0  4.691274  0.013227
# Factor1:Factor2   1.369042   2.0  0.652738  0.524677
# Residual         56.629374  54.0       NaN       NaN

# %%
#  Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Parameters for the F-distribution
df1_values = [5, 10, 20]  # Degrees of freedom for the numerator (between-group variance)
df2_values = [10, 20, 30]  # Degrees of freedom for the denominator (within-group variance)

# Generate x values (the F-statistic range)
x = np.linspace(0, 5, 500)

# Plot the F-distribution for each combination of df1 and df2
plt.figure(figsize=(10, 6))
for df1 in df1_values:
    for df2 in df2_values:
        y = stats.f.pdf(x, df1, df2)  # F-distribution probability density function
        plt.plot(x, y, label=f"df1={df1}, df2={df2}")

# Labeling the plot
plt.title('F-Distribution with Different Degrees of Freedom')
plt.xlabel('F-statistic')
plt.ylabel('Probability Density')
plt.legend(title='Degrees of Freedom', loc='upper right')
plt.grid(True)

# Show the plot
plt.show()

# %%
#  Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means

import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# Simulate data for three different groups
np.random.seed(0)

# Simulating data for three groups with different means
group1 = np.random.normal(loc=20, scale=5, size=50)  # Group 1: mean=20, std=5
group2 = np.random.normal(loc=22, scale=5, size=50)  # Group 2: mean=22, std=5
group3 = np.random.normal(loc=25, scale=5, size=50)  # Group 3: mean=25, std=5

# Create a DataFrame to hold the data
data = pd.DataFrame({
    'Group': ['Group 1'] * 50 + ['Group 2'] * 50 + ['Group 3'] * 50,
    'Values': np.concatenate([group1, group2, group3])
})

# Perform the one-way ANOVA
f_statistic, p_value = stats.f_oneway(group1, group2, group3)

# Print the ANOVA results
print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")

# Interpretation of the results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the group means.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the group means.")

# Visualization of the results using boxplots
plt.figure(figsize=(8, 6))
sns.boxplot(x='Group', y='Values', data=data, palette="Set2")
plt.title('One-Way ANOVA: Comparison of Group Means')
plt.xlabel('Group')
plt.ylabel('Values')
plt.show()
# Out:
# F-statistic: 16.462692949765874
# P-value: 3.5361408587070217e-07
# Reject the null hypothesis: There is a significant difference between the group means.
# <ipython-input-23-ca66058f6bb9>:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Group', y='Values', data=data, palette="Set2")

# %%
#  Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(0)

# Simulate random data for two groups
group1 = np.random.normal(loc=50, scale=10, size=100)  # Group 1: mean=50, std=10
group2 = np.random.normal(loc=55, scale=10, size=100)  # Group 2: mean=55, std=10

# Perform a two-sample t-test (independent t-test)
t_stat, p_value = stats.ttest_ind(group1, group2)

# Print the results of the t-test
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Interpret the results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the group means.")
else:
    print("Fail to reject the null hypothesis: No significant difference between the group means.")

# Visualization of the data using boxplot
plt.figure(figsize=(8, 6))
plt.boxplot([group1, group2], labels=["Group 1", "Group 2"], patch_artist=True)
plt.title('Comparison of Two Groups')
plt.xlabel('Group')
plt.ylabel('Values')
plt.show()
# Out:
# T-statistic: -3.5971927597496247
# P-value: 0.00040627960203623494
# Reject the null hypothesis: There is a significant difference between the group means.
# <ipython-input-24-1e60af5a9661>:30: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2], labels=["Group 1", "Group 2"], patch_artist=True)

# %%
#  Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results

import numpy as np
import scipy.stats as stats

# Simulate data (sample data for a population)
np.random.seed(0)
sample_data = np.random.normal(loc=50, scale=10, size=100)  # mean=50, std=10, sample size=100

# Define the hypothesized population variance (sigma_0^2)
sigma_0_squared = 100  # hypothesized population variance (std^2 = 10^2 = 100)

# Calculate the sample variance (s^2)
sample_variance = np.var(sample_data, ddof=1)  # ddof=1 for sample variance

# Sample size (n)
n = len(sample_data)

# Calculate the Chi-square test statistic
chi_square_stat = (n - 1) * sample_variance / sigma_0_squared

# Degrees of freedom
df = n - 1

# Significance level
alpha = 0.05

# Calculate the critical values for the two-tailed test
chi_square_critical_lower = stats.chi2.ppf(alpha / 2, df)
chi_square_critical_upper = stats.chi2.ppf(1 - alpha / 2, df)

# Print the test statistic and critical values
print(f"Chi-square test statistic: {chi_square_stat}")
print(f"Chi-square critical values: Lower = {chi_square_critical_lower}, Upper = {chi_square_critical_upper}")

# Perform the hypothesis test
if chi_square_stat < chi_square_critical_lower or chi_square_stat > chi_square_critical_upper:
    print("Reject the null hypothesis: The population variance is significantly different from the hypothesized variance.")
else:
    print("Fail to reject the null hypothesis: The population variance is not significantly different from the hypothesized variance.")
# Out:
# Chi-square test statistic: 101.58266192149313
# Chi-square critical values: Lower = 73.36108019128368, Upper = 128.4219886438403
# Fail to reject the null hypothesis: The population variance is not significantly different from the hypothesized variance.

# %%
# D Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results

import numpy as np
import scipy.stats as stats

# Simulate a sample from a normal distribution
np.random.seed(42)
sample = np.random.normal(loc=100, scale=15, size=30)  # mean=100, std=15, n=30

# Hypothesized population variance
sigma_0_squared = 225  # (15^2)

# Sample variance
sample_variance = np.var(sample, ddof=1)
n = len(sample)
df = n - 1

# Chi-square test statistic
chi2_stat = (df * sample_variance) / sigma_0_squared

# Two-tailed test: significance level
alpha = 0.05
chi2_crit_lower = stats.chi2.ppf(alpha / 2, df)
chi2_crit_upper = stats.chi2.ppf(1 - alpha / 2, df)

# Print results
print(f"Sample Variance: {sample_variance:.2f}")
print(f"Chi-square statistic: {chi2_stat:.2f}")
print(f"Chi-square critical values: ({chi2_crit_lower:.2f}, {chi2_crit_upper:.2f})")

# Decision
if chi2_stat < chi2_crit_lower or chi2_stat > chi2_crit_upper:
    print("❌ Reject the null hypothesis: The population variance is significantly different.")
else:
    print("✅ Fail to reject the null hypothesis: No significant difference in population variance.")
# Out:
# Sample Variance: 182.25
# Chi-square statistic: 23.49
# Chi-square critical values: (16.05, 45.72)
# ✅ Fail to reject the null hypothesis: No significant difference in population variance.

# %%
#  Write a Python script to perform a Z-test for comparing proportions between two datasets or groups

import numpy as np
import scipy.stats as stats

def z_test_proportions(x1, n1, x2, n2, alpha=0.05):
    # Sample proportions
    p1 = x1 / n1
    p2 = x2 / n2

    # Pooled proportion
    p_pool = (x1 + x2) / (n1 + n2)

    # Z statistic
    z = (p1 - p2) / np.sqrt(p_pool * (1 - p_pool) * (1/n1 + 1/n2))

    # Two-tailed p-value
    p_value = 2 * (1 - stats.norm.cdf(abs(z)))

    # Critical z for 95% confidence
    z_crit = stats.norm.ppf(1 - alpha / 2)

    print(f"Proportion 1 (p1): {p1:.4f}")
    print(f"Proportion 2 (p2): {p2:.4f}")
    print(f"Z-statistic: {z:.4f}")
    print(f"P-value: {p_value:.4f}")
    print(f"Critical Z-value: ±{z_crit:.2f}")

    if abs(z) > z_crit:
        print("❌ Reject the null hypothesis: Proportions are significantly different.")
    else:
        print("✅ Fail to reject the null hypothesis: No significant difference in proportions.")


z_test_proportions(x1=60, n1=100, x2=45, n2=100)
# Out:
# Proportion 1 (p1): 0.6000
# Proportion 2 (p2): 0.4500
# Z-statistic: 2.1240
# P-value: 0.0337
# Critical Z-value: ±1.96
# ❌ Reject the null hypothesis: Proportions are significantly different.

# %%
# Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def f_test_variances(data1, data2, alpha=0.05):
    # Sample sizes
    n1, n2 = len(data1), len(data2)

    # Sample variances
    var1, var2 = np.var(data1, ddof=1), np.var(data2, ddof=1)

    # Make sure F >= 1 by dividing the larger variance by the smaller
    if var1 > var2:
        f_stat = var1 / var2
        df1, df2 = n1 - 1, n2 - 1
    else:
        f_stat = var2 / var1
        df1, df2 = n2 - 1, n1 - 1

    # Critical F-values for two-tailed test
    f_crit_low = stats.f.ppf(alpha / 2, df1, df2)
    f_crit_high = stats.f.ppf(1 - alpha / 2, df1, df2)

    # P-value
    p_value = 2 * min(stats.f.cdf(f_stat, df1, df2), 1 - stats.f.cdf(f_stat, df1, df2))

    # Print results
    print(f"Sample Variance 1: {var1:.4f}")
    print(f"Sample Variance 2: {var2:.4f}")
    print(f"F-statistic: {f_stat:.4f}")
    print(f"Critical F-values: ({f_crit_low:.4f}, {f_crit_high:.4f})")
    print(f"P-value: {p_value:.4f}")

    if f_stat < f_crit_low or f_stat > f_crit_high:
        print("❌ Reject H₀: The variances are significantly different.")
    else:
        print("✅ Fail to reject H₀: No significant difference in variances.")

    # Visualization
    x = np.linspace(0.01, 5, 500)
    y = stats.f.pdf(x, df1, df2)

    plt.figure(figsize=(8, 4))
    plt.plot(x, y, label="F-distribution", color='blue')
    plt.axvline(f_stat, color='red', linestyle='--', label=f"F-statistic = {f_stat:.2f}")
    plt.axvline(f_crit_low, color='green', linestyle='--', label="Lower Critical Value")
    plt.axvline(f_crit_high, color='green', linestyle='--', label="Upper Critical Value")
    plt.title("F-Test: Comparison of Two Variances")
    plt.xlabel("F value")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Simulate two samples
np.random.seed(0)
data1 = np.random.normal(50, 10, 30)   # std = 10
data2 = np.random.normal(50, 15, 30)   # std = 15

# Run the F-test
f_test_variances(data1, data2)
# Out:
# Sample Variance 1: 121.0723
# Sample Variance 2: 188.0622
# F-statistic: 1.5533
# Critical F-values: (0.4760, 2.1010)
# P-value: 0.2416
# ✅ Fail to reject H₀: No significant difference in variances.

# %%
#  Perform a Chi-square test for goodness of fit with simulated data and analyze the results

import numpy as np
from scipy.stats import chisquare
import matplotlib.pyplot as plt

# Simulate observed data (e.g., rolling a 6-sided die 120 times)
np.random.seed(42)
observed = np.random.choice([1, 2, 3, 4, 5, 6], size=120)
observed_counts = np.bincount(observed)[1:]  # ignore 0th bin (dice starts from 1)

# Define expected frequencies assuming fair die (uniform distribution)
expected_counts = [120 / 6] * 6  # 20 expected for each side

# Chi-square test
chi_stat, p_value = chisquare(f_obs=observed_counts, f_exp=expected_counts)

# Display results
print("Observed Counts:", observed_counts)
print("Expected Counts:", expected_counts)
print(f"Chi-square Statistic: {chi_stat:.4f}")
print(f"P-value: {p_value:.4f}")

if p_value < 0.05:
    print("❌ Reject H₀: The data does not fit the expected distribution.")
else:
    print("✅ Fail to reject H₀: The data fits the expected distribution.")

# Plotting
labels = ['1', '2', '3', '4', '5', '6']
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, observed_counts, width, label='Observed')
bars2 = ax.bar(x + width/2, expected_counts, width, label='Expected', color='orange')

ax.set_xlabel('Die Face')
ax.set_ylabel('Frequency')
ax.set_title('Chi-square Goodness of Fit Test: Die Roll Frequencies')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# Observed Counts: [19 21 16 28 19 17]
# Expected Counts: [20.0, 20.0, 20.0, 20.0, 20.0, 20.0]
# Chi-square Statistic: 4.6000
# P-value: 0.4666
# ✅ Fail to reject H₀: The data fits the expected distribution.
